# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from wordcloud import WordCloud

import re
import string


# Membaca file CSV langsung dari direktori saat ini
df = pd.read_csv("review_byond_playstore.csv", delimiter=",")

# Menampilkan DataFrame
display(df)
# Out:
#                                   Review ID         Username  Rating  \
# 0      6b4af182-7d0a-4b24-a406-b6858709709a  Pengguna Google       5
# 1      3dd1dc9b-4c11-4d83-86f7-7e81a071237b  Pengguna Google       5
# 2      ec205cfe-9a74-46e3-9139-40a3dd08a246  Pengguna Google       5
# 3      ca80546d-2e6f-4c94-9000-d6c19d9079f7  Pengguna Google       1
# 4      d660254a-9834-4184-94a5-a6704ed80e5e  Pengguna Google       5
# ...                                     ...              ...     ...
# 44827  d1cb5821-189a-4a2c-89ff-79d88b2b0b36  Pengguna Google       5
# 44828  6a6c7fe3-4a99-43f2-9d1b-3d48d1003ad3  Pengguna Google       5
# 44829  fbd44595-f93c-47ea-97ce-8facce61d8a7  Pengguna Google       5
# 44830  573558a9-b1a9-4e70-9b33-cf39c3f5a363  Pengguna Google       5
# 44831  f12eab89-0709-4bba-bccc-bd8923ea6042  Pengguna Google       5
#
#                                              Review Text                 Date
# 0      menurut saya aplikasi ini sudah cukup baik, fi...  2025-09-16 02:55:03
# 1      aplikasi ini fiturnya lengkap,bisa bayar semua...  2025-09-16 02:51:01
# 2            Sangat Membantu untuk Keperluan Sehari hari  2025-09-16 02:45:16
# 3      Aplikasi belum ready atau system yang belum re...  2025-09-16 02:43:21
# 4                                      semoga bermanfaat  2025-09-16 02:41:37
# ...                                                  ...                  ...
# 44827  Aplikasi nya keren banget, tampilan interface ...  2024-10-25 14:38:18
# 44828                      #Level Up to the Next Journey  2024-10-25 14:37:59
# 44829                                                 Ok  2024-10-25 14:31:33
# 44830                                              bagus  2024-10-25 14:22:32
# 44831             Aplikasi mobile banking paling lengkap  2024-10-25 14:18:41
#
# [44832 rows x 5 columns]

# %%
# Cek jumlah data yang didapatkan
num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 44832.

# %%
# Cek Struktur DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44832 entries, 0 to 44831
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Review ID    44832 non-null  object
#  1   Username     44832 non-null  object
#  2   Rating       44832 non-null  int64
#  3   Review Text  44832 non-null  object
#  4   Date         44832 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 1.7+ MB

# %%
df.shape
# Out:
# (44832, 5)

# %%
# Cek Nilai Kosong atau Missing Value
df.isnull().sum()
# Out:
# Review ID      0
# Username       0
# Rating         0
# Review Text    0
# Date           0
# dtype: int64

# %%
# Hapus Data Kosong
df = df.dropna(subset=["Review Text", "Rating"])

df.isnull().sum()
# Out:
# Review ID      0
# Username       0
# Rating         0
# Review Text    0
# Date           0
# dtype: int64

# %%
# Cek dan hapus duplikasi data
# Jumlah duplikat
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Hapus duplikat
df = df.drop_duplicates()

df.shape
# Out:
# (44832, 5)
